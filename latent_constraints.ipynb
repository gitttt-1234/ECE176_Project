# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/ECE176_Project/"
# !ls
# Out:
# /content/drive/MyDrive/ECE176_Project
# ac.py			experiment_vaemnist.py	  run_ac_mnist.py
# classifier_run_test.py	latent_constraints.ipynb  run_ac.py
# classifier_test_exp.py	LICENSE.md		  run_classifiermnist.py
# configs			logs			  run.py
# data			models			  run_vaemnist.py
# dataset_mnist.py	__pycache__		  train_classifier_mnist.py
# dataset.py		README.md		  train_classifier.py
# experiment.py		requirements.txt	  utils.py

# %%
# !python3 -m pip install -r requirements.txt
# !python3 -m pip uninstall tensorflow -y
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 KB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 16.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 24.4 MB/s eta 0:00:00
# ...
# Found existing installation: tensorflow 2.11.0
# Uninstalling tensorflow-2.11.0:
#   Successfully uninstalled tensorflow-2.11.0

# %% [markdown]
# ###CIFAR 10

# %%
#general
# !python train_classifier.py -c configs/classifier.yaml -vc configs/vae.yaml -ac configs/ac.yaml
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0, loss = 1.0650
# Accuracy (55.20)
#
# Epoch 1, loss = 1.2071
# Accuracy (64.20)
#
# Epoch 2, loss = 0.7132
# Accuracy (74.20)
#
# Epoch 3, loss = 0.5352
# Accuracy (75.70)
#
# Epoch 4, loss = 0.4711
# Accuracy (76.40)
#
# Epoch 5, loss = 0.7983
# Accuracy (77.50)
#
# Epoch 6, loss = 0.2559
# Accuracy (77.40)
#
# Epoch 7, loss = 0.4197
# Accuracy (76.40)
#
# Epoch 8, loss = 0.0404
# Accuracy (77.90)
#
# Epoch 9, loss = 0.0397
# Accuracy (76.70)
#
# Epoch 10, loss = 0.0602
# Accuracy (78.60)
#
# Epoch 11, loss = 0.1995
# Accuracy (79.20)
#
# Epoch 12, loss = 0.1732
# Accuracy (78.30)
#
# Epoch 13, loss = 0.1181
# Accuracy (78.00)
#
# Epoch 14, loss = 0.1250
# Accuracy (78.60)
#
# Epoch 15, loss = 0.0736
# Accuracy (77.80)
#
# Epoch 16, loss = 0.1953
# Accuracy (77.90)
#
# Epoch 17, loss = 0.0167
# Accuracy (78.40)
#
# Epoch 18, loss = 0.1846
# ...

# %%
#noise
# !python train_classifier.py -c configs/classifier.yaml -vc configs/vae.yaml -ac configs/ac.yaml
# Out:
# exp flag:  1
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0, loss = 1.6100
# Accuracy (52.40)
#
# Epoch 1, loss = 1.2567
# Accuracy (61.20)
#
# Epoch 2, loss = 1.1299
# Accuracy (63.60)
#
# Epoch 3, loss = 1.0124
# Accuracy (70.30)
#
# Epoch 4, loss = 0.7087
# Accuracy (70.50)
#
# Epoch 5, loss = 1.0494
# Accuracy (71.70)
#
# Epoch 6, loss = 0.5286
# Accuracy (75.70)
#
# Epoch 7, loss = 0.6746
# Accuracy (72.90)
#
# Epoch 8, loss = 0.3278
# Accuracy (74.30)
#
# Epoch 9, loss = 0.8457
# Accuracy (74.90)
#
# Epoch 10, loss = 0.5706
# Accuracy (75.80)
#
# Epoch 11, loss = 0.5254
# Accuracy (73.40)
#
# Epoch 12, loss = 0.3034
# Accuracy (73.50)
#
# Epoch 13, loss = 0.3305
# Accuracy (74.60)
#
# Epoch 14, loss = 0.5579
# Accuracy (74.70)
#
# Epoch 15, loss = 0.2616
# Accuracy (73.80)
#
# Epoch 16, loss = 0.4780
# Accuracy (74.80)
#
# Epoch 17, loss = 0.4331
# Accuracy (73.70)
#
# Epoch 18, loss = 0.3455
# ...

# %%
#ac 
# !python train_classifier.py -c configs/classifier.yaml -vc configs/vae.yaml -ac configs/ac.yaml
# Out:
# exp flag:  2
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.9/dist-packages/torch/nn/functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch 0, loss = 1.0383
# Accuracy (55.50)
#
# Epoch 1, loss = 0.7540
# Accuracy (65.50)
#
# Epoch 2, loss = 0.7641
# Accuracy (69.10)
#
# Epoch 3, loss = 0.8331
# Accuracy (74.00)
#
# Epoch 4, loss = 0.6993
# Accuracy (76.60)
#
# Epoch 5, loss = 0.7473
# Accuracy (75.30)
#
# Epoch 6, loss = 0.3916
# Accuracy (75.50)
#
# Epoch 7, loss = 0.6277
# Accuracy (75.30)
#
# Epoch 8, loss = 0.2472
# Accuracy (77.20)
#
# Epoch 9, loss = 0.2701
# Accuracy (76.50)
#
# Epoch 10, loss = 0.3282
# Accuracy (74.60)
#
# Epoch 11, loss = 0.1144
# Accuracy (74.40)
#
# Epoch 12, loss = 0.2558
# Accuracy (74.30)
#
# Epoch 13, loss = 0.1639
# ...

# %% [markdown]
# ###MNIST

# %%
#general
# !python train_classifier_mnist.py -c configs/classifier_mnist.yaml -vc configs/vae_mnist.yaml -ac configs/acmnist.yaml

# %%
#with noise
# !python train_classifier_mnist.py -c configs/classifier_mnist.yaml -vc configs/vae_mnist.yaml -ac configs/acmnist.yaml

# %%
#with ac
# !python train_classifier_mnist.py -c configs/classifier_mnist.yaml -vc configs/vae_mnist.yaml -ac configs/acmnist.yaml
# Out:
# exp flag:  2
# ...
# 100% 9912422/9912422 [00:00<00:00, 211698658.51it/s]
# Extracting /content/drive/MyDrive/ECE176_PR/data/MNIST/raw/train-images-idx3-ubyte.gz to /content/drive/MyDrive/ECE176_PR/data/MNIST/raw
#
# ...
# 100% 28881/28881 [00:00<00:00, 191065763.13it/s]
# Extracting /content/drive/MyDrive/ECE176_PR/data/MNIST/raw/train-labels-idx1-ubyte.gz to /content/drive/MyDrive/ECE176_PR/data/MNIST/raw
#
# ...
# Failed to download (trying next):
# <urlopen error [Errno 99] Cannot assign requested address>
#
# ...
# 100% 1648877/1648877 [00:01<00:00, 1246928.18it/s]
# Extracting /content/drive/MyDrive/ECE176_PR/data/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/drive/MyDrive/ECE176_PR/data/MNIST/raw
#
# ...
# 100% 4542/4542 [00:00<00:00, 27060410.18it/s]
# Extracting /content/drive/MyDrive/ECE176_PR/data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/drive/MyDrive/ECE176_PR/data/MNIST/raw
#
# ...

# %% [markdown]
# ###just

# %%
#normal classifier

# !python train_classifier.py -c configs/classifier.yaml
# Out:
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/utilities/seed.py:48: LightningDeprecationWarning: `pytorch_lightning.utilities.seed.seed_everything` has been deprecated in v1.8.0 and will be removed in v2.0.0. Please use `lightning_fabric.utilities.seed.seed_everything` instead.
#   rank_zero_deprecation(
# Global seed set to 1265
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0, loss = 1.3407
# Accuracy (53.90)
#
# Epoch 1, loss = 0.7358
# Accuracy (65.30)
#
# Epoch 2, loss = 0.7769
# Accuracy (67.60)
#
# Epoch 3, loss = 1.0207
# Accuracy (72.10)
#
# Epoch 4, loss = 0.6977
# Accuracy (73.10)
#
# Epoch 5, loss = 0.5927
# Accuracy (74.00)
#
# Epoch 6, loss = 0.4227
# Accuracy (74.60)
#
# Epoch 7, loss = 0.2280
# Accuracy (74.10)
#
# Epoch 8, loss = 0.3762
# Accuracy (75.20)
#
# Epoch 9, loss = 0.3287
# Accuracy (73.50)
#
# Epoch 10, loss = 0.1029
# Accuracy (74.70)
#
# Epoch 11, loss = 0.3240
# ...

# %%
#with noise
# !python train_classifier.py -c configs/classifier.yaml -vc configs/vae.yaml -ac configs/ac.yaml
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [42,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [42,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [42,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [42,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [42,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...

# %%
# !python run.py -c configs/vae.yaml

# %%
# !python run_constraint.py -c configs/ac_vae.yaml -vc configs/vae.yaml
# Out:
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/utilities/seed.py:48: LightningDeprecationWarning: `pytorch_lightning.utilities.seed.seed_everything` has been deprecated in v1.8.0 and will be removed in v2.0.0. Please use `lightning_fabric.utilities.seed.seed_everything` instead.
#   rank_zero_deprecation(
# Global seed set to 1265
# Files already downloaded and verified
# Files already downloaded and verified
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=0)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=0)` instead.
#   rank_zero_deprecation(
# GPU available: True (cuda), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...

# %%
# %rm -rf "/content/drive/MyDrive/Colab Notebooks/ECE176_PR/PyTorch-VAE/logs/VanillaVAE"
