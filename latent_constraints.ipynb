# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "drive/MyDrive/ECE176_Project/"
# !ls
# Out:
# /content/drive/MyDrive/ECE176_Project
# ac.py			  models
# CIFAR10C		  __pycache__
# classifier_run_test.py	  README.md
# classifier_test_exp.py	  requirements.txt
# configs			  run_ac_mnist.py
# corruptions.txt		  run_ac.py
# data			  run_classifiermnist.py
# dataset_cifar10c.py	  run.py
# dataset_mnist.py	  run_vaemnist.py
# dataset.py		  train_classifier_cifar_10c_test.py
# experiment.py		  train_classifier_d_mnist.py
# experiment_vaemnist.py	  train_classifier_mnist.py
# latent_constraints.ipynb  train_classifier.py
# LICENSE.md		  utils.py
# logs

# %%
# !python3 -m pip install -r requirements.txt
# !python3 -m pip uninstall tensorflow -y
# !python3 -m pip install ddu_dirty_mnist
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 KB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 40.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 27.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 25.4 MB/s eta 0:00:00
# ...
# Found existing installation: tensorflow 2.11.0
# Uninstalling tensorflow-2.11.0:
#   Successfully uninstalled tensorflow-2.11.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ###CIFAR 10

# %%
# %matplotlib inline
# %run train_classifier.py -c configs/classifier.yaml -vc configs/vae.yaml -ac configs/ac.yaml
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ---------------CIFAR-10 generic classifer---------------
# Epoch 0, loss = 1.7503
# Accuracy (62.97)
#
# Epoch 1, loss = 0.6117
# Accuracy (70.89)
#
# Epoch 2, loss = 0.9406
# Accuracy (72.54)
#
# Epoch 3, loss = 0.7657
# Accuracy (73.94)
#
# Epoch 4, loss = 0.7663
# Accuracy (74.91)
#
# Epoch 5, loss = 0.7808
# Accuracy (75.26)
#
# Epoch 6, loss = 0.3540
# Accuracy (74.46)
#
# Epoch 7, loss = 0.1847
# Accuracy (74.91)
#
# Epoch 8, loss = 0.0994
# Accuracy (74.87)
#
# Epoch 9, loss = 0.2364
# Accuracy (75.29)
#
# Epoch 10, loss = 0.0258
# Accuracy (75.35)
#
# Epoch 11, loss = 0.0095
# Accuracy (75.93)
#
# Epoch 12, loss = 0.3623
# Accuracy (75.44)
#
# Epoch 13, loss = 0.0020
# Accuracy (75.09)
#
# Epoch 14, loss = 0.0140
# Accuracy (74.72)
#
# Epoch 15, loss = 0.0164
# Accuracy (75.35)
#
# Epoch 16, loss = 0.0063
# Accuracy (76.65)
#
# Epoch 17, loss = 0.0431
# Accuracy (75.64)
#
# ...

# %% [markdown]
# ###CIFAR10C

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/ECE176_Project

# %%
# !tar -xvf  'CIFAR-10-C.tar' -C '/content/drive/MyDrive/ECE176_Project/CIFAR10C'
# Out:
# CIFAR-10-C/
# CIFAR-10-C/fog.npy
# CIFAR-10-C/jpeg_compression.npy
# CIFAR-10-C/zoom_blur.npy
# CIFAR-10-C/speckle_noise.npy
# CIFAR-10-C/glass_blur.npy
# CIFAR-10-C/spatter.npy
# CIFAR-10-C/shot_noise.npy
# CIFAR-10-C/defocus_blur.npy
# CIFAR-10-C/elastic_transform.npy
# CIFAR-10-C/gaussian_blur.npy
# CIFAR-10-C/frost.npy
# CIFAR-10-C/saturate.npy
# CIFAR-10-C/brightness.npy
# CIFAR-10-C/snow.npy
# CIFAR-10-C/gaussian_noise.npy
# CIFAR-10-C/motion_blur.npy
# CIFAR-10-C/contrast.npy
# CIFAR-10-C/impulse_noise.npy
# CIFAR-10-C/labels.npy
# CIFAR-10-C/pixelate.npy

# %%
# %matplotlib inline
# %run train_classifier_cifar_10c_test.py -c configs/classifier.yaml -vc configs/vae.yaml -ac configs/ac.yaml
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ---------------CIFAR-10 generic classifer---------------
# Epoch 0, loss = 1.1847
# Accuracy (64.13)
#
# Epoch 1, loss = 0.5041
# Accuracy (71.50)
#
# Epoch 2, loss = 0.6499
# Accuracy (73.51)
#
# Epoch 3, loss = 0.3838
# Accuracy (74.05)
#
# Epoch 4, loss = 0.3461
# Accuracy (74.78)
#
# Epoch 5, loss = 0.1873
# Accuracy (75.23)
#
# Epoch 6, loss = 0.0335
# Accuracy (75.28)
#
# Epoch 7, loss = 0.1382
# Accuracy (76.00)
#
# Epoch 8, loss = 0.2078
# Accuracy (75.13)
#
# Epoch 9, loss = 0.2207
# Accuracy (75.08)
#
# Epoch 10, loss = 0.3818
# Accuracy (75.73)
#
# Epoch 11, loss = 0.4282
# Accuracy (75.51)
#
# Epoch 12, loss = 0.2183
# Accuracy (75.40)
#
# Epoch 13, loss = 0.2553
# Accuracy (75.31)
#
# Epoch 14, loss = 0.5032
# Accuracy (75.39)
#
# Epoch 15, loss = 0.4224
# Accuracy (75.61)
#
# Epoch 16, loss = 0.0436
# Accuracy (76.18)
#
# Epoch 17, loss = 0.0059
# Accuracy (75.56)
#
# ...

# %%
# !ls /content/drive/MyDrive/ECE176_Project/CIFAR10C/
# Out:
# CIFAR-10-C  CIFAR-10-C.tar

# %% [markdown]
# ###MNIST

# %%
# %matplotlib inline
# %run train_classifier_mnist.py -c configs/classifier_mnist.yaml -vc configs/vae_mnist.yaml -ac configs/acmnist.yaml
# Out:
# MNIST
# ---------------MNIST generic classifer---------------
# Epoch 0, loss = 0.1543
# Accuracy (96.44)
#
# Epoch 1, loss = 0.3109
# Accuracy (97.45)
#
# Epoch 2, loss = 0.0406
# Accuracy (97.31)
#
# Epoch 3, loss = 0.2418
# Accuracy (97.51)
#
# Epoch 4, loss = 0.6126
# Accuracy (97.72)
#
# Epoch 5, loss = 0.0677
# Accuracy (97.53)
#
# Epoch 6, loss = 0.3022
# Accuracy (97.60)
#
# Epoch 7, loss = 0.0040
# Accuracy (97.55)
#
# Epoch 8, loss = 0.0480
# Accuracy (97.48)
#
# Epoch 9, loss = 0.0149
# Accuracy (97.53)
#
# Epoch 10, loss = 0.0406
# Accuracy (97.71)
#
# Epoch 11, loss = 0.0015
# Accuracy (97.77)
#
# Epoch 12, loss = 0.0258
# Accuracy (97.75)
#
# Epoch 13, loss = 0.0029
# Accuracy (97.67)
#
# Epoch 14, loss = 0.0009
# Accuracy (97.93)
#
# Epoch 15, loss = 0.0596
# Accuracy (97.89)
#
# Epoch 16, loss = 0.0478
# Accuracy (97.89)
#
# Epoch 17, loss = 0.0002
# Accuracy (97.93)
#
# Epoch 18, loss = 0.0641
# Accuracy (97.78)
#
# Epoch 19, loss = 0.0019
# Accuracy (98.12)
#
# ...

# %% [markdown]
# ###DMNIST test

# %%
# %matplotlib inline
# %run train_classifier_d_mnist.py -c configs/classifier_mnist.yaml -vc configs/vae_mnist.yaml -ac configs/acmnist.yaml
# Out:
# DMNIST
# ---------------MNIST generic classifer---------------
# Epoch 0, loss = 0.1643
# Accuracy (96.76)
#
# Epoch 1, loss = 0.0781
# Accuracy (97.19)
#
# Epoch 2, loss = 0.0748
# Accuracy (97.46)
#
# Epoch 3, loss = 0.0586
# Accuracy (97.58)
#
# Epoch 4, loss = 0.2720
# Accuracy (97.47)
#
# Epoch 5, loss = 0.0237
# Accuracy (97.70)
#
# Epoch 6, loss = 0.0160
# Accuracy (97.75)
#
# Epoch 7, loss = 0.0193
# Accuracy (97.71)
#
# Epoch 8, loss = 0.0411
# Accuracy (97.94)
#
# Epoch 9, loss = 0.0130
# Accuracy (97.90)
#
# Epoch 10, loss = 0.0147
# Accuracy (98.02)
#
# Epoch 11, loss = 0.1259
# Accuracy (97.83)
#
# Epoch 12, loss = 0.1629
# Accuracy (98.04)
#
# Epoch 13, loss = 0.0102
# Accuracy (97.64)
#
# Epoch 14, loss = 0.0017
# Accuracy (97.95)
#
# Epoch 15, loss = 0.0004
# Accuracy (97.97)
#
# Epoch 16, loss = 0.0552
# Accuracy (98.03)
#
# Epoch 17, loss = 0.0123
# Accuracy (97.82)
#
# Epoch 18, loss = 0.0005
# Accuracy (98.12)
#
# Epoch 19, loss = 0.1847
# Accuracy (97.78)
#
# ...

# %% [markdown]
# #30 epochs
# Run 1:
# Test Accuracy: on Dirty Mnist
# Accuracy (36.38)
#
# Test Accuracy: on Dirty Mnist
# Accuracy (57.47)
#
# Run 2:
# Test Accuracy: on Dirty Mnist
# Accuracy (53.86)
#
# Test Accuracy: on Dirty Mnist
# Accuracy (58.31)
#
# Run 3:
# Test Accuracy: on Dirty Mnist
# Accuracy (39.49)
#
# Test Accuracy: on Dirty Mnist
# Accuracy (55.58)
